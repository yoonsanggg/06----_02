# %%
import time
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from bs4 import BeautifulSoup as bs
import pandas as pd
# from tqdm import tqdm
import urllib.request
import requests
import os

# %%
options = Options()
options.add_experimental_option('detach', True)
options.add_argument('--start-maximized')
service = Service(ChromeDriverManager().install())

driver = webdriver.Chrome(service=service, options=options)
search='권고'
pageNo=1
url=f'https://www.korea.kr/totalSearch.do?srchFlag=N&keyword={search}&resultKeyword={search}&sort=date&scnt={pageNo}&punit=10&where=news_korea_2023&dateRange=all&range=ALL&op=and&multiFlag=Y&news_type=pol'
driver.get(url)
time.sleep(1)

searchWord_input =driver.find_element(By.ID,'topSearchKeywordSr')

tags = driver.find_elements(By.CSS_SELECTOR,'span.text strong a')
res=[]
while pageNo <= 12:
    for tag in tags:
        tmp = {'링크': tag.get_attribute('href'), '제목': tag.text.strip('\n\t')}
        res.append(tmp)
    pageNo += 1
    time.sleep(2)

# %%
res
# Out:
# [{'링크': 'https://www.korea.kr/news/policyNewsView.do?newsId=148934824',
#   '제목': '송산그린시티, 스마트그린산업단지 지정…온실가스 27.7% 감축 기대'},
#  {'링크': 'https://www.korea.kr/news/policyNewsView.do?newsId=148934633',
#   '제목': '문체부 “클린스만, 홍명보 감독 선임과정 모두 규정과 절차 위반”'},
#  {'링크': 'https://www.korea.kr/news/policyNewsView.do?newsId=148934535',
#   '제목': '윤석열 정부 출범 2년 5개월…국방·보훈분야 고충민원 2021건 해결'},
#  {'링크': 'https://www.korea.kr/news/policyNewsView.do?newsId=148934427',
#   '제목': 'OECD, 올해 한국 경제성장률 2.5%·내년 2.2%…안정적 성장 전망'},
#  {'링크': 'https://www.korea.kr/news/policyNewsView.do?newsId=148934212',
#   '제목': 'LPG 누출 시 작업자에 스피커로 경보…스마트폰 차단 장치도 개발'},
#  {'링크': 'https://www.korea.kr/news/policyNewsView.do?newsId=148934116',
#   '제목': '평균보다 나트륨·당류 10% 이상 적은 건면 등 ‘덜 짠’ 표시 가능'},
#  {'링크': 'https://www.korea.kr/news/policyNewsView.do?newsId=148934076',
#   '제목': '인플루엔자 국가예방접종 20일부터 시작…동절기 유행 대비'},
#  {'링크': 'https://www.korea.kr/news/policyNewsView.do?newsId=148934066',
# ...
